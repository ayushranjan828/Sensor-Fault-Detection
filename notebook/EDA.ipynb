# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
wafer = pd.read_csv(r"wafer_23012020_041211.csv")
print("Shape of dataset: ",wafer.shape)
wafer.head()
# Out:
# Shape of dataset:  (100, 592)
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
# ...

# %%
wafer.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
wafer.rename(columns={"Unnamed: 0" : "wafer"}, inplace=True)
wafer.head(2)
# Out:
#        wafer  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
#
#    Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589  Sensor-590  \
# 0      0.0033      2.4069      0.0545      0.0184      0.0055     33.7876
# 1      0.0031      2.3020      0.0545      0.0184      0.0055     33.7876
#
#    Good/Bad
# 0        -1
# 1         1
#
# [2 rows x 592 columns]

# %%
# Split data into train and test
from sklearn.model_selection import train_test_split

wafers_train, wafers_test = train_test_split(wafer, test_size=20, random_state=42)

# %%
print("Wafter test size: ", wafers_test.shape)
print("Wafter train size: ", wafers_train.shape)

wafers_train.info()
# Out:
# Wafter test size:  (20, 592)
# Wafter train size:  (80, 592)
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 55 to 51
# Columns: 592 entries, wafer to Good/Bad
# dtypes: float64(494), int64(97), object(1)
# memory usage: 370.6+ KB

# %%
wafers_train.describe()
# Out:
#           Sensor-1     Sensor-2     Sensor-3     Sensor-4   Sensor-5  \
# count    79.000000    80.000000    78.000000    78.000000  78.000000
# mean   3019.048228  2494.058875  2202.758988  1519.467071   1.201382
# std      72.665372    68.166898    31.633772   471.962104   0.365870
# min    2889.670000  2254.990000  2114.666700   978.783200   0.753100
# 25%    2975.425000  2452.517500  2189.966700  1111.543600   0.850075
# 50%    3004.390000  2502.445000  2200.955600  1308.647900   1.164250
# 75%    3065.730000  2532.755000  2212.866700  1997.641600   1.383000
# max    3221.210000  2664.520000  2315.266700  2363.641200   2.207300
#
#        Sensor-6    Sensor-7   Sensor-8   Sensor-9  Sensor-10  ...  Sensor-582  \
# count      78.0   78.000000  78.000000  80.000000  80.000000  ...   27.000000
# mean      100.0   96.881160   0.122158   1.460087   0.000946  ...   63.785093
# std         0.0    5.520108   0.002062   0.072159   0.010865  ...   30.722790
# ...

# %%
# Category in our target feature

wafers_train["Good/Bad"].value_counts()
# Highly imbalance data
# Out:
# Good/Bad
# -1    74
#  1     6
# Name: count, dtype: int64

# %%
# Check missing value in target feature
wafers_train["Good/Bad"].isna().sum()
# Out:
# 0

# %%
wafers_train.isna().sum().sum()
# Out:
# 1822

# %%
# Check missing value in dependent feature variable
wafers_train.isna().sum().sum() / (wafers_train.shape[0] * (wafers_train.shape[1] - 1))
# Out:
# 0.038536379018612524

# %%
plt.figure(figsize=(15, 100))

for i, col in enumerate(wafers_train.columns[1:51]):
    plt.subplot(60, 3, i+1)
    sns.displot(x = wafers_train[col], color='indianred')
    plt.xlabel(col, weight='bold')
    plt.tight_layout()
# Out:
# c:\Users\ayush\anaconda3\Lib\site-packages\seaborn\axisgrid.py:453: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize)

# %%
# Select 50 random sensor

random_50_sensor_idx = []
for i in range(50):
    if i not in random_50_sensor_idx:
        random_50_sensor_idx.append(np.random.randint(1, 591))

# %%
plt.figure(figsize=(15, 100))

for i, col in enumerate(wafers_train.columns[random_50_sensor_idx]):
    plt.subplot(60, 3, i+1)
    sns.displot(x=wafers_train[col], color='indianred')
    plt.xlabel(col, weight='bold')
    plt.tight_layout()
# Out:
# c:\Users\ayush\anaconda3\Lib\site-packages\seaborn\axisgrid.py:453: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize)

# %%
# Drop column with zero standing deviation as they are not influenced the target variable

def get_col_with_zero_std_dev(df: pd.DataFrame):
    cols_to_drop = []
    num_cols = [col for col in df.columns if df[col].dtype != 'O']

    for col in num_cols:
        if df[col].std() == 0:
            cols_to_drop.append(col)
    return cols_to_drop


def get_redundant_col(df: pd.DataFrame, missing_thresh = .7):
    cols_missing_ratios = df.isna().sum().div(df.shape[0])
    cols_to_drop = list(cols_missing_ratios[cols_missing_ratios > missing_thresh].index)
    return cols_to_drop

# %%
wafers_train.dtypes
# Out:
# wafer          object
# Sensor-1      float64
# Sensor-2      float64
# Sensor-3      float64
# Sensor-4      float64
#                ...
# Sensor-587    float64
# Sensor-588    float64
# Sensor-589    float64
# Sensor-590    float64
# Good/Bad        int64
# Length: 592, dtype: object

# %%
cols_to_drop_1 = get_redundant_col(wafers_train, missing_thresh=0.7)
cols_to_drop_1
# Out:
# ['Sensor-158', 'Sensor-159', 'Sensor-293', 'Sensor-294']

# %%
cols_to_drop_2 = get_col_with_zero_std_dev(df = wafers_train)
cols_to_drop_2.append("wafer")
cols_to_drop_2
# Out:
# ['Sensor-6',
#  'Sensor-14',
#  'Sensor-43',
#  'Sensor-50',
#  'Sensor-53',
#  'Sensor-70',
#  'Sensor-75',
#  'Sensor-98',
#  'Sensor-142',
#  'Sensor-150',
#  'Sensor-179',
#  'Sensor-180',
#  'Sensor-187',
#  'Sensor-190',
#  'Sensor-191',
#  'Sensor-192',
#  'Sensor-193',
#  'Sensor-194',
#  'Sensor-195',
#  'Sensor-207',
#  'Sensor-210',
#  'Sensor-227',
#  'Sensor-230',
#  'Sensor-231',
#  'Sensor-232',
#  'Sensor-233',
#  'Sensor-234',
#  'Sensor-235',
#  'Sensor-236',
#  'Sensor-237',
#  'Sensor-238',
#  'Sensor-241',
#  'Sensor-242',
#  'Sensor-243',
#  'Sensor-244',
#  'Sensor-257',
#  'Sensor-258',
#  'Sensor-259',
#  'Sensor-260',
#  'Sensor-261',
#  'Sensor-262',
#  'Sensor-263',
#  'Sensor-264',
#  'Sensor-265',
#  'Sensor-266',
#  'Sensor-267',
#  'Sensor-277',
#  'Sensor-285',
#  'Sensor-314',
#  'Sensor-315',
#  'Sensor-316',
#  'Sensor-323',
#  'Sensor-326',
#  'Sensor-327',
#  'Sensor-328',
#  'Sensor-329',
#  'Sensor-330',
#  'Sensor-331',
#  'Sensor-343',
# ...

# %%
cols_to_drop = cols_to_drop_1 + cols_to_drop_2
cols_to_drop
# Out:
# ['Sensor-158',
#  'Sensor-159',
#  'Sensor-293',
#  'Sensor-294',
#  'Sensor-6',
#  'Sensor-14',
#  'Sensor-43',
#  'Sensor-50',
#  'Sensor-53',
#  'Sensor-70',
#  'Sensor-75',
#  'Sensor-98',
#  'Sensor-142',
#  'Sensor-150',
#  'Sensor-179',
#  'Sensor-180',
#  'Sensor-187',
#  'Sensor-190',
#  'Sensor-191',
#  'Sensor-192',
#  'Sensor-193',
#  'Sensor-194',
#  'Sensor-195',
#  'Sensor-207',
#  'Sensor-210',
#  'Sensor-227',
#  'Sensor-230',
#  'Sensor-231',
#  'Sensor-232',
#  'Sensor-233',
#  'Sensor-234',
#  'Sensor-235',
#  'Sensor-236',
#  'Sensor-237',
#  'Sensor-238',
#  'Sensor-241',
#  'Sensor-242',
#  'Sensor-243',
#  'Sensor-244',
#  'Sensor-257',
#  'Sensor-258',
#  'Sensor-259',
#  'Sensor-260',
#  'Sensor-261',
#  'Sensor-262',
#  'Sensor-263',
#  'Sensor-264',
#  'Sensor-265',
#  'Sensor-266',
#  'Sensor-267',
#  'Sensor-277',
#  'Sensor-285',
#  'Sensor-314',
#  'Sensor-315',
#  'Sensor-316',
#  'Sensor-323',
#  'Sensor-326',
#  'Sensor-327',
#  'Sensor-328',
# ...

# %%
# Separate Feature and Label Out

x, y = wafers_train.drop(cols_to_drop, axis=1), wafers_train[["Good/Bad"]]

# Dependent feature variable
print("Shape of the feature now: ", x.shape)
x.head()
# Out:
# Shape of the feature now:  (80, 465)
#     Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-7  Sensor-8  \
# 55       NaN   2532.45  2191.1333  2197.6570    1.1569   89.7222    0.1251
# 88   3221.21   2391.20  2189.9667  1046.6212    0.8662  102.3622    0.1208
# 26   2951.85   2525.00  2189.5777  1320.3197    1.3459  100.7744    0.1234
# 42   2982.07   2447.06  2199.6334  1242.8420    1.4083   99.2178    0.1221
# 69   3058.08   2524.60  2192.3778  1110.5453    0.8147   99.2922    0.1226
#
#     Sensor-9  Sensor-10  Sensor-11  ...  Sensor-582  Sensor-583  Sensor-584  \
# 55    1.5762     0.0028    -0.0066  ...         NaN      0.4936      0.0113
# 88    1.4756    -0.0025     0.0025  ...         NaN      0.4940      0.0123
# 26    1.5590    -0.0032     0.0135  ...     53.8577      0.5025      0.0178
# 42    1.4542     0.0142    -0.0064  ...         NaN      0.4993      0.0151
# 69    1.4958     0.0004     0.0037  ...     24.6547      0.4974      0.0171
#
# ...

# %%
# Independent or Target variable
print("Shape of the feature now: ", y.shape)
y.head()
# Out:
# Shape of the feature now:  (80, 1)
#     Good/Bad
# 55        -1
# 88        -1
# 26        -1
# 42        -1
# 69        -1

# %%
# Data Transformation
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler

imputer = KNNImputer(n_neighbors=1)
preprocessing_pipeline = Pipeline(
    steps=[('Imputer', imputer), ('Scalar', RobustScaler())]
)

preprocessing_pipeline
# Out:
# Pipeline(steps=[('Imputer', KNNImputer(n_neighbors=1)),
#                 ('Scalar', RobustScaler())])

# %%
# Transform  "wafers_train" feature

x_trans = preprocessing_pipeline.fit_transform(x)
print("Shape of Transformed feature set: ", x_trans.shape)
x_trans
# Out:
# Shape of Transformed feature set:  (80, 465)
# array([[ 0.33605305,  0.37395233, -0.41140354, ...,  0.        ,
#          0.75955556,  0.        ],
#        [ 2.48926049, -1.38644649, -0.46213134, ..., -0.51612903,
#         -0.52610857,  0.        ],
#        [-0.61709673,  0.28110298, -0.47904641, ...,  0.58064516,
#         -0.08775867,  0.        ],
#        ...,
#        [-0.04728269,  0.21779093,  1.04722739, ...,  0.12903226,
#         -0.17805529,  0.        ],
#        [ 0.01891307,  0.87459106,  0.5486156 , ...,  0.29032258,
#          0.28421459,  0.        ],
#        [ 0.84659075,  0.3813055 , -0.57325767, ..., -0.16129032,
#         -0.20782888,  0.        ]])

# %%
from imblearn.combine import SMOTETomek

X, y = x_trans[:,:-1], y
resampler = SMOTETomek(sampling_strategy="auto")
X_res, y_res = resampler.fit_resample(X, y)

# %%
print("Before resampling, sahpe of traning instance: ",np.c_[X,y].shape)
print("After resampling, sahpe of traning instance: ",np.c_[X_res,y_res].shape)
# Out:
# Before resampling, sahpe of traning instance:  (80, 465)
# After resampling, sahpe of traning instance:  (148, 465)

# %%
# Target cats after Resampling
print(np.unique(y_res))
print(f"Vaalue count: \n-1: {len(y_res[y_res == -1])}, 1: {len(y_res[y_res == 1])}")
# Out:
# [-1  1]
# Vaalue count:
# -1: 148, 1: 148

# %%
# Prepare the test set

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_res, y_res, test_size=1/3, random_state=42)

print(f"train set: {X_train.shape, Y_train.shape}")
print(f"test set: {X_test.shape, Y_test.shape}")
# Out:
# train set: ((98, 464), (98, 1))
# test set: ((50, 464), (50, 1))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf.fit(X_train, Y_train)

# Predict on the test set
y_pred = rf.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(Y_test, y_pred))
print("\nClassification Report:\n", classification_report(Y_test, y_pred))
# Out:
# Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00        25
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50
# c:\Users\ayush\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
